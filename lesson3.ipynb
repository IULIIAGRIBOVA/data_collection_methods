# %%
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint


headers = {'User-agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2224.3 Safari/537.36'}
main_link = 'https://kaliningrad.hh.ru'

response = requests.get(main_link+'/search/vacancy?clusters=true&enable_snippets=true&text='+'Python'+'&showClusters=true&area=2&page=0',headers=headers).text
#'https://kaliningrad.hh.ru/search/vacancy?L_is_autosearch=false&area=16&clusters=true&enable_snippets=true&text=python&page=0'


flag_next = 1
while flag_next == 1:
    soup = bs(response,'lxml')
    vacancy_block = soup.find('div',{'class':'vacancy-serp'})
    vacancy_list = vacancy_block.find_all('div',{'class':'vacancy-serp-item'})
    jobs = []
    for vacancy in vacancy_list:
        jobs_data = {}
        vacancy_name = vacancy.find('a', {'class':'bloko-link'}).text
        vacancy_href = vacancy.find('a', {'class':'bloko-link'})['href']
        vacancy_salary = None
        salary_min = None
        salary_max = None
        currency = None
        vacancy_salary = vacancy.find('span', {'data-qa':'vacancy-serp__vacancy-compensation'})

        if vacancy_salary != None:
            vacancy_salary = vacancy_salary.text
            vacancy_salary=vacancy_salary.replace(u'\xa0', u'')
            #print(vacancy_salary)
            salaries=vacancy_salary.split('-')
            if len(salaries)>1:
                salary_min = int(salaries[0])
                salaries_1 = salaries[1].split(' ')
                if len(salaries_1)>1:
                    salary_max = int(salaries_1[0])
                    currency = salaries_1[1]
                else:
                    salary_max = int(salaries_1[0])
            else:
                salaries_1=vacancy_salary.split('от ')
                if len(salaries_1)>1:
                    salaries_2 = salaries_1[1].split(' ')
                    salary_min = int(salaries_2[0])
                    if len(salaries_2)>1:
                        currency = salaries_2[1]
                else:
                    salaries_2=vacancy_salary.split('до ')
                    if len(salaries_2)>1:
                        salaries_3 = salaries_2[1].split(' ')
                        salary_max = int(salaries_3[0])
                        if len(salaries_3)>1:
                            currency = salaries_3[1]
                    else:
                        salary_min = int(vacancy_salary)
                        salary_max = int(vacancy_salary)

            jobs_data['name'] = vacancy_name   
            jobs_data['salary_min'] = salary_min  
            jobs_data['salary_max'] = salary_max
            jobs_data['currency'] = currency
            jobs_data['link'] = vacancy_href
            jobs_data['site'] = main_link
            vacancy_id = vacancy_href.replace(u'https://kaliningrad.hh.ru/vacancy/', u'')
            vacancy_id = vacancy_id.replace(u'?query=Python', u'')
            jobs_data['_id'] = vacancy_id+'_hh'
            jobs.append(jobs_data)

    #ищем на странице кнопку "дальше"
    next_button = soup.find('a',{'bloko-button HH-Pager-Controls-Next HH-Pager-Control'})
    if next_button == None:
        flag_next = 0
    else:
        response = requests.get(main_link+next_button['href'], headers=headers).text

# %%
headers = {'User-agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2224.3 Safari/537.36'}
#main_link = 'https://www.superjob.ru'
main_link = 'https://russia.superjob.ru'
response = requests.get(main_link+'/vacancy/search/?keywords=python').text
flag_next = 1
while flag_next == 1:
    soup = bs(response,'lxml')
    #print(soup)
    vacancy_block = soup.find('div',{'class':'_1ID8B'})
    #pprint(vacancy_block)
    vacancy_list = vacancy_block.find_all('div',{'class':'_3zucV _1fMKr undefined _1NAsu'})
   # print(vacancy_list)
    #print(len(vacancy_list))
    for vacancy in vacancy_list:
        jobs_data = {}
        #print(vacancy)
        vacancy_div = vacancy.find('div',{'class':'jNMYr GPKTZ _1tH7S'})
        if vacancy_div != None:
            vacancy_name = vacancy_div.find('a').text
            #print(vacancy_name) 
            vacancy_href = main_link+vacancy.find('a')['href']
            #print(vacancy_href)
            vacancy_salary = None
            salary_min = None
            salary_max = None
            currency = None
            vacancy_salary = vacancy_div.find('span', {'class':'_3mfro _2Wp8I PlM3e _2JVkc _2VHxz'})
            
            if vacancy_salary != None:
                vacancy_salary = vacancy_salary.text
                vacancy_salary=vacancy_salary.replace(u'\xa0', u'')
                vacancy_salary=vacancy_salary.replace(u'руб.', u' руб')
                
                #print(vacancy_salary)
                if vacancy_salary != 'По договоренности' and vacancy_salary != 'По договорённости':
                    vacancy_salary=vacancy_salary.replace(u'до', u'до ')
                    vacancy_salary=vacancy_salary.replace(u'от', u'от ')
                    salaries=vacancy_salary.split('—')
                    if len(salaries)>1:
                        salary_min = int(salaries[0])
                        salaries_1 = salaries[1].split(' ')
                        if len(salaries_1)>1:
                            salary_max = int(salaries_1[0])
                            currency = salaries_1[1]
                        else:
                            salary_max = int(salaries_1[0])
                    else:
                        salaries_1=vacancy_salary.split('от ')
                        if len(salaries_1)>1:
                            salaries_2 = salaries_1[1].split(' ')
                            salary_min = int(salaries_2[0])
                            if len(salaries_2)>1:
                                currency = salaries_2[1]
                        else:
                            salaries_2=vacancy_salary.split('до ')
                            if len(salaries_2)>1:
                                salaries_3 = salaries_2[1].split(' ')
                                salary_max = int(salaries_3[0])
                                if len(salaries_3)>1:
                                    currency = salaries_3[1]
                            else:
                                print(vacancy_salary)
                                salaries_1 = vacancy_salary.split(' ')
                                salary_min = int(salaries_1[0])
                                salary_max = int(salaries_1[0])
                                if len(salaries_1)>1:
                                    currency = salaries_1[1]
                         

                jobs_data['name'] = vacancy_name   
                jobs_data['salary_min'] = salary_min  
                jobs_data['salary_max'] = salary_max
                jobs_data['currency'] = currency
                jobs_data['link'] = vacancy_href
               
                #print(jobs_data['link'])
                vacancy_id = vacancy_href.replace(u'https://russia.superjob.ru/vakansii/', u'')
                vacancy_id = vacancy_id.replace(u'.html', u'')
                number = -1
                vacancy_id_reversed = vacancy_id[::-1]
                for val in vacancy_id_reversed:
                    number = number+1
                    if val == '-':
                        break
                vacancy_id = vacancy_id_reversed[:number]
                vacancy_id = vacancy_id[::-1]
                #print(vacancy_id)
                jobs_data['_id'] = vacancy_id+'_sj'   
                jobs_data['site'] = main_link
                jobs.append(jobs_data)
        

       

       

    #ищем на странице кнопку "дальше"
    next_button = soup.find('a',{'icMQ_ _1_Cht _3ze9n f-test-button-dalshe f-test-link-Dalshe'})
    if next_button == None:
        flag_next = 0
    else:
        #print(next_button['href'])
        response = requests.get(main_link+next_button['href'], headers=headers).text

# %%
from pymongo import MongoClient

# %%
client = MongoClient('localhost',27017)
db = client['vacancy_db']

vacancies = db.vacancy
#vacancies.delete_many({})
insert_jobs = []
for job in jobs:
    #ищем в базе вакансию по полю _id
    vacancy_list = vacancies.find({'_id':job['_id']}) 
    #если такой вакансии не нашлось, складываем её в список вакансий, которые нужно добавить в базу
    if len(list(vacancy_list)) == 0 :
        insert_jobs.append(job)

if len(insert_jobs) != 0:
    vacancies.insert_many(insert_jobs)
    
for vacancy in vacancies.find({}):
    pprint(vacancy)
# Out:
# boy
# boy
# boy
# boy
# {'_id': '37406780_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37406780?query=Python',
#  'name': 'Системный аналитик',
#  'salary_max': 150000,
#  'salary_min': None,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37401334_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37401334?query=Python',
#  'name': 'QA Engineer (Middle)',
#  'salary_max': 150000,
#  'salary_min': 100000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '36950721_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/36950721?query=Python',
#  'name': 'Middle+ Frontend-разработчик (Анимация Canvas) Удаленно',
#  'salary_max': 150000,
#  'salary_min': None,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37390391_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37390391?query=Python',
#  'name': 'Middle Android Developer',
#  'salary_max': 180000,
#  'salary_min': 104000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37387672_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37387672?query=Python',
#  'name': 'Разработчик BI (QlikView, Qlik Sense)',
#  'salary_max': 150000,
#  'salary_min': 70000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '36890159_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/36890159?query=Python',
#  'name': 'Разработчик PostgreSQL',
#  'salary_max': None,
#  'salary_min': 90000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37391427_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37391427?query=Python',
#  'name': 'Разработчик платформы создания моделей МО',
#  'salary_max': None,
#  'salary_min': 120000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37445137_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37445137?query=Python',
#  'name': 'Системный администратор Linux',
#  'salary_max': None,
#  'salary_min': 120000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '34036604_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/software-34036604.html',
#  'name': 'Software / Solutions Architect with Python',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34018176_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-34018176.html',
#  'name': 'Разработчик (программист) Python',
#  'salary_max': 80000,
#  'salary_min': 65000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33935766_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/python-33935766.html',
#  'name': 'Python / Django Developer (Middle)',
#  'salary_max': 80000,
#  'salary_min': 40000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34009801_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/programmist-python-34009801.html',
#  'name': 'Программист Python',
#  'salary_max': None,
#  'salary_min': 70000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33998693_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/full-stack-veb-programmist-python-33998693.html',
#  'name': 'Full-stack-веб-программист python/javascript',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33987344_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/python-developer-33987344.html',
#  'name': 'Python developer',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34028789_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/python-34028789.html',
#  'name': 'Python / GO developer',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33938805_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-prilozhenij-33938805.html',
#  'name': 'Разработчик приложений (Python)',
#  'salary_max': 150000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34008592_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/python-34008592.html',
#  'name': 'Python / React.js разработчик',
#  'salary_max': 120000,
#  'salary_min': 100000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34043652_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-programmist-34043652.html',
#  'name': 'Инженер-программист',
#  'salary_max': None,
#  'salary_min': 50000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34043930_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-34043930.html',
#  'name': 'Системный администратор, IT-специалист',
#  'salary_max': None,
#  'salary_min': 80000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33961440_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/data-inzhener-33961440.html',
#  'name': 'Дата-инженер / Data Engineer',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34076850_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/glavnyj-inzhener-po-prikladnomu-soprovozhdeniyu-integracionnyh-reshenij-34076850.html',
#  'name': 'Главный инженер по прикладному сопровождению интеграционных решений',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33885602_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/veduschij-programmist-razrabotchik-fullstack-33885602.html',
#  'name': 'Ведущий программист-разработчик Fullstack',
#  'salary_max': None,
#  'salary_min': 100000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33495885_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/veduschij-sistemnyj-administrator-33495885.html',
#  'name': 'Ведущий системный администратор',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '32382712_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/uchitel-informatiki-32382712.html',
#  'name': 'Учитель информатики',
#  'salary_max': None,
#  'salary_min': 78000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34035407_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/web-programmist-34035407.html',
#  'name': 'Web-программист, Web-разработчик',
#  'salary_max': None,
#  'salary_min': 20621,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33089687_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-33089687.html',
#  'name': 'Инженер, техник',
#  'salary_max': None,
#  'salary_min': 35000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34000185_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/analitik-dannyh-34000185.html',
#  'name': 'Аналитик данных',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33939917_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/starshij-it-menedzher-33939917.html',
#  'name': 'Старший ИТ-менеджер',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34034531_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/starshij-inzhener-po-avtomatizacii-testirovaniya-34034531.html',
#  'name': 'Старший инженер по автоматизации тестирования (Python)',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33990047_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/senior-devops-inzhener-33990047.html',
#  'name': 'Senior DevOps-инженер',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34007624_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/analitik-dannyh-34007624.html',
#  'name': 'Аналитик данных',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '31814280_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/specialist-sektora-operacionnoj-effektivnosti-resursov-31814280.html',
#  'name': 'Специалист сектора операционной эффективности ресурсов',
#  'salary_max': None,
#  'salary_min': 50000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34058370_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-php-34058370.html',
#  'name': 'Разработчик PHP',
#  'salary_max': 250000,
#  'salary_min': 200000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '32618908_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/veduschij-ekspert-po-supp-32618908.html',
#  'name': 'Ведущий эксперт по СУПП',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33838909_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-seti-peredachi-dannyh-33838909.html',
#  'name': 'Инженер сети передачи данных',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34007072_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-tehnicheskoj-podderzhki-34007072.html',
#  'name': 'Инженер технической поддержки',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34048915_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-java-34048915.html',
#  'name': 'Разработчик Java',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33543776_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-po-kachestvu-33543776.html',
#  'name': 'Инженер по качеству (для людей с ограниченными возможностями)',
#  'salary_max': None,
#  'salary_min': 70000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33473129_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/web-analitik-33473129.html',
#  'name': 'Web-аналитик',
#  'salary_max': 120000,
#  'salary_min': 100000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33988355_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-bi-33988355.html',
#  'name': 'Разработчик BI',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34082308_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/zamestitel-glavnogo-inzhenera-po-infrastrukture-34082308.html',
#  'name': 'Заместитель главного инженера по инфраструктуре',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33938281_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/veduschij-programmist-otdela-upravleniya-i-razvitiya-kisu-pao-mrsk-centra-i-privolzhya-33938281.html',
#  'name': 'Ведущий программист отдела управления и развития КИСУ ПАО МРСК '
#          'Центра и Приволжья (ф-л Нижновэнерго)',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34037249_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/qa-automation-engineer-34037249.html',
#  'name': 'QA Automation Engineer / Инженер по тестированию',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34087214_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-34087214.html',
#  'name': 'Системный администратор',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34053494_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-po-sistemam-it-monitoringa-34053494.html',
#  'name': 'Инженер по системам ИТ-мониторинга',
#  'salary_max': 200000,
#  'salary_min': 180000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34067119_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/data-scientist-34067119.html',
#  'name': 'Data Scientist',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34086302_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/analitik-dannyh-34086302.html',
#  'name': 'Аналитик данных (Data Analyst/Data Scientist)',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33935774_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/prepodavatel-kompyuternyh-it-kursov-i-dizajna-33935774.html',
#  'name': 'Преподаватель компьютерных IT курсов и дизайна',
#  'salary_max': 150000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34036349_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/starshij-inzhener-devops-34036349.html',
#  'name': 'Старший инженер DevOps',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34007660_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-etl-34007660.html',
#  'name': 'Инженер ETL',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34079705_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/rukovoditel-napravleniya-34079705.html',
#  'name': 'Руководитель направления',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34067111_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/senior-data-analyst-34067111.html',
#  'name': 'Senior data analyst',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33092773_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-programmist-33092773.html',
#  'name': 'Инженер-программист',
#  'salary_max': None,
#  'salary_min': 40000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33865314_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/glavnyj-razrabotchik-33865314.html',
#  'name': 'Главный разработчик',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34001508_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/veduschij-inzhener-cod-34001508.html',
#  'name': 'Ведущий инженер ЦОД',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '31183225_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/analitik-31183225.html',
#  'name': 'Аналитик',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34009684_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/full-stack-razrabotchik-34009684.html',
#  'name': 'Full-stack-разработчик',
#  'salary_max': None,
#  'salary_min': 105000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34085720_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/administrator-hadoop-34085720.html',
#  'name': 'Администратор Hadoop (BI / DWH)',
#  'salary_max': 220000,
#  'salary_min': 180000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33921626_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/web-programmist-33921626.html',
#  'name': 'Web-программист, Web-разработчик (удалённо)',
#  'salary_max': None,
#  'salary_min': 30000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33364026_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/prepodavatel-programmirovaniya-i-informatiki-33364026.html',
#  'name': 'Преподаватель программирования и информатики',
#  'salary_max': None,
#  'salary_min': 18000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34048831_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/uchitel-informatiki-34048831.html',
#  'name': 'Учитель информатики (педагог по программированию)',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33864238_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/genetik-analitik-dannyh-33864238.html',
#  'name': 'Генетик-аналитик данных / Data scientist',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '11311026_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/assistent-11311026.html',
#  'name': 'Ассистент/доцент кафедры информатики и компьютерных технологий',
#  'salary_max': 100000,
#  'salary_min': 80000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33997533_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/konsultant-proektirovaniya-i-vnedreniya-sistem-monitoringa-informacionnoj-bezopasnosti-33997533.html',
#  'name': 'Консультант проектирования и внедрения систем мониторинга '
#          'информационной безопасности (SIEM)',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33996076_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/devops-inzhener-33996076.html',
#  'name': 'DevOps-инженер',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '27807302_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/uchitel-informatiki-27807302.html',
#  'name': 'Учитель информатики',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33865766_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-programmist-33865766.html',
#  'name': 'Инженер-программист',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '31060829_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/uchitel-informatiki-31060829.html',
#  'name': 'Учитель информатики',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34036428_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/big-data-developer-34036428.html',
#  'name': 'Big Data Developer (Palantir Foundry)',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33508905_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/analitik-dannyh-33508905.html',
#  'name': 'Аналитик данных',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33998954_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-v-otdel-sborki-po-33998954.html',
#  'name': 'Системный администратор в отдел сборки ПО',
#  'salary_max': None,
#  'salary_min': 41000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33840080_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/oblachnyj-inzhener-33840080.html',
#  'name': 'Облачный инженер / Инженер систем хранения данных',
#  'salary_max': None,
#  'salary_min': 150000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33954153_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-devops-33954153.html',
#  'name': 'Инженер Devops',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34069324_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/senior-backend-developer-34069324.html',
#  'name': 'Senior Backend Developer',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33986797_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-33986797.html',
#  'name': 'Системный администратор',
#  'salary_max': 30000,
#  'salary_min': 27000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '30030397_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-programmist-30030397.html',
#  'name': 'Инженер-программист',
#  'salary_max': None,
#  'salary_min': 60000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33983628_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/starshij-razrabotchik-vstraivaemyh-sistem-i-vstroennogo-po-33983628.html',
#  'name': 'Старший разработчик встраиваемых систем и встроенного ПО / Senior '
#          'Embedded Developer',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34065795_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/bi-analitik-34065795.html',
#  'name': 'BI-аналитик (программист)',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34028550_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/s-34028550.html',
#  'name': 'С++ developer',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33947500_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/data-scientist-33947500.html',
#  'name': 'Data Scientist',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33945656_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/backend-razrabotchik-33945656.html',
#  'name': 'Backend-разработчик',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33977967_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/veb-programmist-33977967.html',
#  'name': 'Веб-программист',
#  'salary_max': None,
#  'salary_min': 60000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34061081_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-raschetchik-34061081.html',
#  'name': 'Инженер-расчетчик (прочность)',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33562126_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/zamestitel-rukovoditelya-it-direkcii-33562126.html',
#  'name': 'Заместитель руководителя ИТ-дирекции',
#  'salary_max': 120000,
#  'salary_min': 100000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '32075249_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-32075249.html',
#  'name': 'Системный администратор',
#  'salary_max': 35000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34020232_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-php-34020232.html',
#  'name': 'Разработчик PHP',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33832459_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-linux-33832459.html',
#  'name': 'Системный администратор Linux',
#  'salary_max': None,
#  'salary_min': 50000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33935066_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/sap-application-support-specialist-33935066.html',
#  'name': 'SAP Application Support Specialist',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34036667_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/kotlin-team-lead-developer-34036667.html',
#  'name': 'Kotlin Team Lead Developer',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34079737_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/veduschij-inzhener-v-divizion-integracionnye-servisy-34079737.html',
#  'name': 'Ведущий инженер в дивизион Интеграционные сервисы',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33998838_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-sistem-videonablyudeniya-33998838.html',
#  'name': 'Разработчик систем видеонаблюдения',
#  'salary_max': None,
#  'salary_min': 65000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33983598_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/issledovatel-bezopasnosti-web-prilozhenij-33983598.html',
#  'name': 'Исследователь безопасности web-приложений (пентест) / '
#          'Web-application Security Researcher (security)',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34065056_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/devops-inzhener-34065056.html',
#  'name': 'DevOps-инженер',
#  'salary_max': 125000,
#  'salary_min': 100000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33970231_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/biomedicinskij-statistik-33970231.html',
#  'name': 'Биомедицинский статистик',
#  'salary_max': None,
#  'salary_min': 80000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34017290_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/qa-engineer-34017290.html',
#  'name': 'QA engineer (тестировщик)',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34043847_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/starshij-arhitektor-big-data-34043847.html',
#  'name': 'Старший архитектор Big Data',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34036589_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/senior-build-engineer-34036589.html',
#  'name': 'Senior Build Engineer',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34036606_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/senior-data-scientist-34036606.html',
#  'name': 'Senior Data Scientist',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34036862_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/senior-big-data-devops-engineer-34036862.html',
#  'name': 'Senior Big Data DevOps Engineer',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34043498_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/klyuchevoj-razrabotchik-tableau-34043498.html',
#  'name': 'Ключевой разработчик Tableau',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34043816_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/senior-big-data-engineer-34043816.html',
#  'name': 'Senior Big Data Engineer',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34043114_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/lead-big-data-software-engineer-for-content-platform-34043114.html',
#  'name': 'Lead Big Data Software Engineer for Content Platform',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34036661_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/senior-engineer-cyber-security-34036661.html',
#  'name': 'Senior Engineer Cyber Security',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34040209_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/veduschij-specialist-po-dannym-34040209.html',
#  'name': 'Ведущий специалист по данным',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34040108_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/veduschij-bigdata-inzhener-34040108.html',
#  'name': 'Ведущий BigData инженер',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33998649_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/programmist-testirovschik-33998649.html',
#  'name': 'Программист-тестировщик (производительность мобильных приложений)',
#  'salary_max': None,
#  'salary_min': 56000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33983601_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/web-razrabotchik-full-stack-33983601.html',
#  'name': 'Web-разработчик Full stack',
#  'salary_max': 200000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33983451_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/team-lead-33983451.html',
#  'name': 'Team lead / Ведущий разработчик',
#  'salary_max': 300000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33983617_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/reverse-engineer-33983617.html',
#  'name': 'Reverse Engineer / Вирусный аналитик',
#  'salary_max': 300000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33846645_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/programmist-c-33846645.html',
#  'name': 'Программист C/С++',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33846983_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/programmist-mikrokontrollerov-33846983.html',
#  'name': 'Программист микроконтроллеров',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33788781_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/ml-33788781.html',
#  'name': 'ML/NLP Architect / ML/NLP Архитектор',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33788780_sj',
#  'currency': None,
#  'link': 'https://russia.superjob.ru/vakansii/nlp-engineer-33788780.html',
#  'name': 'NLP Engineer / NLP инженер',
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '37530238_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37530238?query=Python',
#  'name': 'Data Scientist',
#  'salary_max': 160000,
#  'salary_min': None,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37139454_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37139454?query=Python',
#  'name': 'Backend разработчик',
#  'salary_max': 160000,
#  'salary_min': 120000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37375334_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37375334?query=Python',
#  'name': 'Стажер-Автоматизатор тестирования (QA Automation) - Web, Python',
#  'salary_max': 25000,
#  'salary_min': None,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '36647989_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/36647989?query=Python',
#  'name': 'Machine Learning Engineer / Data Scientist (DS Team)',
#  'salary_max': None,
#  'salary_min': 180000,
#  'site': 'https://kaliningrad.hh.ru'}

# %%
#функция, которая возвращает вакансии с зарплатой больше задданного числа
def find_vacancies(salary):
    for user in vacancies.find({'$or':[{'salary_max':{'$gt':salary}},{'salary_min':{'$gt':salary}}]}):   
        pprint(user)

# %%
find_vacancies(55000)
# Out:
# {'_id': '37406780_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37406780?query=Python',
#  'name': 'Системный аналитик',
#  'salary_max': 150000,
#  'salary_min': None,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37401334_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37401334?query=Python',
#  'name': 'QA Engineer (Middle)',
#  'salary_max': 150000,
#  'salary_min': 100000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '36950721_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/36950721?query=Python',
#  'name': 'Middle+ Frontend-разработчик (Анимация Canvas) Удаленно',
#  'salary_max': 150000,
#  'salary_min': None,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37390391_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37390391?query=Python',
#  'name': 'Middle Android Developer',
#  'salary_max': 180000,
#  'salary_min': 104000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37387672_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37387672?query=Python',
#  'name': 'Разработчик BI (QlikView, Qlik Sense)',
#  'salary_max': 150000,
#  'salary_min': 70000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '36890159_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/36890159?query=Python',
#  'name': 'Разработчик PostgreSQL',
#  'salary_max': None,
#  'salary_min': 90000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37391427_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37391427?query=Python',
#  'name': 'Разработчик платформы создания моделей МО',
#  'salary_max': None,
#  'salary_min': 120000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37445137_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37445137?query=Python',
#  'name': 'Системный администратор Linux',
#  'salary_max': None,
#  'salary_min': 120000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '34018176_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-34018176.html',
#  'name': 'Разработчик (программист) Python',
#  'salary_max': 80000,
#  'salary_min': 65000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33935766_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/python-33935766.html',
#  'name': 'Python / Django Developer (Middle)',
#  'salary_max': 80000,
#  'salary_min': 40000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34009801_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/programmist-python-34009801.html',
#  'name': 'Программист Python',
#  'salary_max': None,
#  'salary_min': 70000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33938805_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-prilozhenij-33938805.html',
#  'name': 'Разработчик приложений (Python)',
#  'salary_max': 150000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34008592_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/python-34008592.html',
#  'name': 'Python / React.js разработчик',
#  'salary_max': 120000,
#  'salary_min': 100000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34043930_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-34043930.html',
#  'name': 'Системный администратор, IT-специалист',
#  'salary_max': None,
#  'salary_min': 80000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33885602_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/veduschij-programmist-razrabotchik-fullstack-33885602.html',
#  'name': 'Ведущий программист-разработчик Fullstack',
#  'salary_max': None,
#  'salary_min': 100000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '32382712_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/uchitel-informatiki-32382712.html',
#  'name': 'Учитель информатики',
#  'salary_max': None,
#  'salary_min': 78000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34058370_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-php-34058370.html',
#  'name': 'Разработчик PHP',
#  'salary_max': 250000,
#  'salary_min': 200000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33543776_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-po-kachestvu-33543776.html',
#  'name': 'Инженер по качеству (для людей с ограниченными возможностями)',
#  'salary_max': None,
#  'salary_min': 70000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33473129_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/web-analitik-33473129.html',
#  'name': 'Web-аналитик',
#  'salary_max': 120000,
#  'salary_min': 100000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34053494_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-po-sistemam-it-monitoringa-34053494.html',
#  'name': 'Инженер по системам ИТ-мониторинга',
#  'salary_max': 200000,
#  'salary_min': 180000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33935774_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/prepodavatel-kompyuternyh-it-kursov-i-dizajna-33935774.html',
#  'name': 'Преподаватель компьютерных IT курсов и дизайна',
#  'salary_max': 150000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33865314_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/glavnyj-razrabotchik-33865314.html',
#  'name': 'Главный разработчик',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34009684_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/full-stack-razrabotchik-34009684.html',
#  'name': 'Full-stack-разработчик',
#  'salary_max': None,
#  'salary_min': 105000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34085720_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/administrator-hadoop-34085720.html',
#  'name': 'Администратор Hadoop (BI / DWH)',
#  'salary_max': 220000,
#  'salary_min': 180000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '11311026_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/assistent-11311026.html',
#  'name': 'Ассистент/доцент кафедры информатики и компьютерных технологий',
#  'salary_max': 100000,
#  'salary_min': 80000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33840080_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/oblachnyj-inzhener-33840080.html',
#  'name': 'Облачный инженер / Инженер систем хранения данных',
#  'salary_max': None,
#  'salary_min': 150000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '30030397_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/inzhener-programmist-30030397.html',
#  'name': 'Инженер-программист',
#  'salary_max': None,
#  'salary_min': 60000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33977967_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/veb-programmist-33977967.html',
#  'name': 'Веб-программист',
#  'salary_max': None,
#  'salary_min': 60000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33562126_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/zamestitel-rukovoditelya-it-direkcii-33562126.html',
#  'name': 'Заместитель руководителя ИТ-дирекции',
#  'salary_max': 120000,
#  'salary_min': 100000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33998838_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/razrabotchik-sistem-videonablyudeniya-33998838.html',
#  'name': 'Разработчик систем видеонаблюдения',
#  'salary_max': None,
#  'salary_min': 65000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '34065056_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/devops-inzhener-34065056.html',
#  'name': 'DevOps-инженер',
#  'salary_max': 125000,
#  'salary_min': 100000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33970231_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/biomedicinskij-statistik-33970231.html',
#  'name': 'Биомедицинский статистик',
#  'salary_max': None,
#  'salary_min': 80000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33998649_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/programmist-testirovschik-33998649.html',
#  'name': 'Программист-тестировщик (производительность мобильных приложений)',
#  'salary_max': None,
#  'salary_min': 56000,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33983601_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/web-razrabotchik-full-stack-33983601.html',
#  'name': 'Web-разработчик Full stack',
#  'salary_max': 200000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33983451_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/team-lead-33983451.html',
#  'name': 'Team lead / Ведущий разработчик',
#  'salary_max': 300000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '33983617_sj',
#  'currency': 'руб',
#  'link': 'https://russia.superjob.ru/vakansii/reverse-engineer-33983617.html',
#  'name': 'Reverse Engineer / Вирусный аналитик',
#  'salary_max': 300000,
#  'salary_min': None,
#  'site': 'https://russia.superjob.ru'}
# {'_id': '37530238_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37530238?query=Python',
#  'name': 'Data Scientist',
#  'salary_max': 160000,
#  'salary_min': None,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '37139454_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/37139454?query=Python',
#  'name': 'Backend разработчик',
#  'salary_max': 160000,
#  'salary_min': 120000,
#  'site': 'https://kaliningrad.hh.ru'}
# {'_id': '36647989_hh',
#  'currency': 'руб.',
#  'link': 'https://kaliningrad.hh.ru/vacancy/36647989?query=Python',
#  'name': 'Machine Learning Engineer / Data Scientist (DS Team)',
#  'salary_max': None,
#  'salary_min': 180000,
#  'site': 'https://kaliningrad.hh.ru'}
